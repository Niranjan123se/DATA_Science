# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
# Note: Here Exception class refers to the base class for all the exceptions.
# Q2. Write a python program to print Python Exception Hierarchy.
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.
# Q5. Explain ImportError. What is ModuleNotFoundError?
# Q6. List down some best practices for exception handling in python.

# %% [raw]
# ans to 1
#
# We have ti use the Exception class becouse the main logic is wwriteen in to the Main Exception class that who the exception will show in the compiler outcome and it will aslo rease any other predefined excption of the syaatem..

# %%
# ans to 2
'''
to print the exception hierache=y we need to import the inspect module 

'''
import inspect
# will define pur custom function for the printing the  name of subclass
def class_exc(self, ind= 0 ):
#      new we will print the name of the class 
    print('-' * ind, self.__name__)
#     now we have to itrate throughthe sub_clas 
    for i in self.__subclasses__():
        class_exc(i, ind + 3)
print("hierarchy for the build in excemption is: ")

inspect.getclasstree(inspect.getmro(BaseException))
class_exc(BaseException)
# Out:
# hierarchy for the build in excemption is:
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- herror
# --------- gaierror
# --------- timeout
# --------- SSLError
# ------------ SSLCertVerificationError
# ...

# %%
'''
ans to 3
when artheatic opration is not doable on the specific problem then such error occur 
eg 1. ZeroDivisionError occure when we try to divid ethe no with 0
2. OverFlowError
'''
# 1. code
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13956\2782817059.py in <module>
#       6 '''
#       7 # 1. code
# ----> 8 10/0
#
# ZeroDivisionError: division by zero

# %%
# 2
import math
print(math.exp(1000))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13956\790541606.py in <module>
#       1 import math
# ----> 2 print(math.exp(1000))
#
# OverflowError: math range error

# %%
# ans to 4 
'''
LookupError is raised when something is not found.  eg calling a key in dict which is not defind 
1. keyError when we tyr too access they which is not defined 
2. IndexError when we exceed the index of a list or tupple 
'''
# 1
dict= {"k1" : "my key", "k2": "your key"}
dict["k3"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13956\2169677952.py in <module>
#       7
#       8 dict= {"k1" : "my key", "k2": "your key"}
# ----> 9 dict["k3"]
#
# KeyError: 'k3'

# %%
# 2 
l = [1,2]
l[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13956\2098966231.py in <module>
#       1 # 2
#       2 l = [1,2]
# ----> 3 l[2]
#
# IndexError: list index out of range

# %%
# Q 5 ans
# import error when we try to import some file or module in the program and the some is not found then such is called the importEror 
import IDontKmow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13956\613494095.py in <module>
#       1 # Q 5 ans
#       2 # import error when we try to import some file or module in the program and the some is not found then such is called the importEror
# ----> 3 import IDontKmow
#
# ModuleNotFoundError: No module named 'IDontKmow'

# %% [markdown]
# use always a specific exception
# exception of 10/0 is a zero Division error
# print always a mesage we are handling the zero divison message
# always try to log the error
# import thr logging and set the basic congbfig file
# make sure the loggig is is readable
# use the specific error
# documeet all the error
# clean up all the resourses like clouse all the file clouse all the data base connection
